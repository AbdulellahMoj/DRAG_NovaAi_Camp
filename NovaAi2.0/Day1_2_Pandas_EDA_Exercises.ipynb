# %% [markdown]
# <img src="../assets/Header_NovaAi_Camp2.0.png" alt="NovaAi Camp 2.0 Header" width="100%">
#
# # Day 1: Pandas & EDA - Practice Exercises 🏋️
#
# ## Welcome to Your First Data Analysis Challenge!
#
# Now it's time to practice what you've learned! In this notebook, you'll work with **real USA Housing data** and complete tasks on your own.
#
# ### 📊 About the Dataset
#
# **Dataset:** USA Housing Prices
# **Source:** [Kaggle - USA Housing Dataset](https://www.kaggle.com/datasets/vedavyasv/usa-housing)
#
# This dataset contains information about house sales in the USA. Since house price is a continuous number (not categories), this is called a **regression problem**.
#
# ### 📝 Columns in the Dataset:
#
# | Column Name | Description |
# |-------------|-------------|
# | **Avg. Area Income** | Average income of residents in the city where the house is located |
# | **Avg. Area House Age** | Average age of houses in the same city |
# | **Avg. Area Number of Rooms** | Average number of rooms for houses in the same city |
# | **Avg. Area Number of Bedrooms** | Average number of bedrooms for houses in the same city |
# | **Area Population** | Population of the city where the house is located |
# | **Price** | Price that the house was sold for (TARGET variable) |
# | **Address** | Address of the house |
#
# ---
#
# ## 🎯 Your Mission:
#
# Complete all tasks in this notebook. Each task has:
# - ✅ **Clear instructions** on what to do
# - 💡 **Hints** to guide you
# - 🎯 **Expected outcome** so you know if you're right
#
# ### How to Use This Notebook:
#
# 1. Read each task carefully
# 2. Write your code in the empty cell below each task
# 3. Run your code and check the output
# 4. Compare with the expected outcome
# 5. If stuck, check the hints!
#
# ---
#
# ## 📚 What You'll Practice:
#
# 1. ✅ Loading and exploring data
# 2. ✅ Inspecting data quality
# 3. ✅ Filtering and selecting data
# 4. ✅ Cleaning messy data
# 5. ✅ Creating new features
# 6. ✅ Aggregating and grouping
# 7. ✅ Visualizing patterns
#
# Let's get started! 🚀

# %% [markdown]
# ---
#
# # Part 1: Setup and Data Loading 📥
#
# ## Task 1.1: Import Libraries
#
# **Your task:** Import the necessary libraries for this exercise.
#
# **What you need to import:**
# - `pandas` as `pd`
# - `numpy` as `np`
#
# **Expected outcome:** No errors, and a success message printed.

# %%
# Write your code here



# Print success message

# %% [markdown]
# ## Task 1.2: Load the Dataset
#
# **Your task:** Load the USA Housing dataset from the provided URL.
#
# **Dataset URL:**
# ```
# https://raw.githubusercontent.com/rashida048/Datasets/master/USA_Housing.csv
# ```
#
# **Instructions:**
# 1. Use `pd.read_csv()` to load the data
# 2. Store it in a variable called `housing`
# 3. Print a success message
#
# 💡 **Hint:** Remember the syntax: `variable_name = pd.read_csv('url')`
#
# **Expected outcome:** Data loaded successfully with a confirmation message.

# %%
# URL for the dataset
url = "https://raw.githubusercontent.com/rashida048/Datasets/master/USA_Housing.csv"

# Write your code here to load the data



# Print success message

# %% [markdown]
# ---
#
# # Part 2: Data Exploration 🔍
#
# ## Task 2.1: First Look at the Data
#
# **Your task:** Display the first 7 rows of the dataset.
#
# 💡 **Hint:** Use the `.head()` method with a number as parameter.
#
# **Expected outcome:** You should see 7 rows with all columns.

# %%
# Write your code here

# %% [markdown]
# ## Task 2.2: Check the Last Rows
#
# **Your task:** Display the last 5 rows of the dataset.
#
# 💡 **Hint:** Use the `.tail()` method.
#
# **Expected outcome:** You should see the last 5 rows.

# %%
# Write your code here

# %% [markdown]
# ## Task 2.3: Dataset Dimensions
#
# **Your task:** Find out how many rows and columns the dataset has.
#
# **Instructions:**
# 1. Use `.shape` to get the dimensions
# 2. Print a message like: "The dataset has X rows and Y columns"
#
# 💡 **Hint:** `.shape` returns a tuple: (rows, columns). Access them using `.shape[0]` and `.shape[1]`
#
# **Expected outcome:** A message showing the exact number of rows and columns.

# %%
# Write your code here

# %% [markdown]
# ## Task 2.4: Column Names
#
# **Your task:** Get a list of all column names in the dataset.
#
# 💡 **Hint:** Use `.columns.tolist()`
#
# **Expected outcome:** A Python list of all column names.

# %%
# Write your code here

# %% [markdown]
# ## Task 2.5: General Information
#
# **Your task:** Display general information about the dataset.
#
# **Instructions:**
# 1. Use `.info()` to get information about data types and missing values
# 2. Answer these questions (write your answers as comments):
#    - How many total entries are there?
#    - Are there any missing values?
#    - What data types do you see?
#
# 💡 **Hint:** The `.info()` method shows everything you need.
#
# **Expected outcome:** A summary table showing columns, non-null counts, and data types.

# %%
# Write your code here


# Answer the questions as comments:
# Q1: How many total entries? 
# Answer: 

# Q2: Are there any missing values?
# Answer: 

# Q3: What data types do you see?
# Answer:

# %% [markdown]
# ## Task 2.6: Statistical Summary
#
# **Your task:** Display statistical summary for all numerical columns.
#
# **Instructions:**
# 1. Use `.describe()` to get statistics
# 2. Answer these questions (write as comments):
#    - What is the average house price?
#    - What is the most expensive house?
#    - What is the cheapest house?
#
# 💡 **Hint:** Look at the 'Price' column in the describe output.
#
# **Expected outcome:** A table with statistics (count, mean, std, min, max, quartiles) for each numerical column.

# %%
# Write your code here


# Answer the questions:
# Q1: What is the average house price?
# Answer: 

# Q2: What is the most expensive house?
# Answer: 

# Q3: What is the cheapest house?
# Answer:

# %% [markdown]
# ---
#
# # Part 3: Data Selection & Filtering 🎯
#
# ## Task 3.1: Select Single Column
#
# **Your task:** Select and display only the 'Price' column.
#
# **Instructions:**
# 1. Select the 'Price' column
# 2. Display the first 10 values
#
# 💡 **Hint:** Use `housing['Price'].head(10)`
#
# **Expected outcome:** A Series showing the first 10 house prices.

# %%
# Write your code here

# %% [markdown]
# ## Task 3.2: Select Multiple Columns
#
# **Your task:** Create a subset with only these columns:
# - 'Address'
# - 'Price'
# - 'Avg. Area Number of Bedrooms'
#
# Display the first 10 rows of this subset.
#
# 💡 **Hint:** Use double brackets: `housing[['col1', 'col2', 'col3']]`
#
# **Expected outcome:** A DataFrame with only 3 columns and 10 rows.

# %%
# Write your code here

# %% [markdown]
# ## Task 3.3: Filter Expensive Houses
#
# **Your task:** Find all houses that cost more than $1,500,000.
#
# **Instructions:**
# 1. Create a filter for houses where Price > 1,500,000
# 2. Store the result in a variable called `expensive_houses`
# 3. Print how many expensive houses were found
# 4. Display the first 5 expensive houses
#
# 💡 **Hint:** Use boolean masking: `housing[housing['Price'] > 1500000]`
#
# **Expected outcome:** A count and a DataFrame showing expensive houses.

# %%
# Write your code here



# Print count


# Display first 5

# %% [markdown]
# ## Task 3.4: Filter by Multiple Conditions (AND)
#
# **Your task:** Find houses that meet ALL these conditions:
# - Price is less than $800,000
# - Number of bedrooms is exactly 5
# - Area population is greater than 30,000
#
# **Instructions:**
# 1. Create the filter using `&` for AND
# 2. Remember to wrap each condition in parentheses!
# 3. Print how many houses match
# 4. Display all matching houses
#
# 💡 **Hint:** `housing[(condition1) & (condition2) & (condition3)]`
#
# **Expected outcome:** A count and DataFrame of houses matching all criteria.

# %%
# Write your code here

# %% [markdown]
# ## Task 3.5: Filter by Multiple Conditions (OR)
#
# **Your task:** Find houses where EITHER condition is true:
# - Price is greater than $2,000,000 (very expensive)
# - OR Number of rooms is greater than 9 (very large)
#
# **Instructions:**
# 1. Create the filter using `|` for OR
# 2. Print how many houses match
# 3. Display the first 10 matching houses
#
# 💡 **Hint:** `housing[(condition1) | (condition2)]`
#
# **Expected outcome:** A count and DataFrame showing luxury or large houses.

# %%
# Write your code here

# %% [markdown]
# ---
#
# # Part 4: Data Cleaning 🧹
#
# ## Task 4.1: Check for Missing Values
#
# **Your task:** Check if there are any missing values in the dataset.
#
# **Instructions:**
# 1. Use `.isnull().sum()` to count missing values per column
# 2. Calculate the percentage of missing values for each column
# 3. Print both the count and percentage
#
# 💡 **Hint:** Percentage = (missing_count / total_rows) * 100
#
# **Expected outcome:** A summary showing missing value counts and percentages for each column.

# %%
# Write your code here


# Count missing values


# Calculate percentage

# %% [markdown]
# ## Task 4.2: Check for Duplicates
#
# **Your task:** Check if there are any duplicate rows in the dataset.
#
# **Instructions:**
# 1. Use `.duplicated().sum()` to count duplicates
# 2. Print the number of duplicate rows
# 3. If there are duplicates, display them
#
# 💡 **Hint:** Use `.duplicated()` to find duplicates
#
# **Expected outcome:** A count of duplicate rows (if any).

# %%
# Write your code here

# %% [markdown]
# ## Task 4.3: Check Data Types
#
# **Your task:** Verify that all columns have the correct data types.
#
# **Instructions:**
# 1. Display the data type of each column using `.dtypes`
# 2. Check if any numerical columns are stored as objects (text)
# 3. Answer: Are all data types correct?
#
# 💡 **Hint:** Numerical columns should be float64 or int64, not object.
#
# **Expected outcome:** A list of columns with their data types.

# %%
# Write your code here


# Answer: Are all data types correct?
# Answer:

# %% [markdown]
# ---
#
# # Part 5: Feature Engineering 🔧
#
# ## Task 5.1: Create Price Category
#
# **Your task:** Create a new column called 'Price_Category' that categorizes houses as:
# - 'Budget': Price < $1,000,000
# - 'Mid-Range': Price between $1,000,000 and $1,500,000
# - 'Luxury': Price > $1,500,000
#
# **Instructions:**
# 1. Use `.apply()` with a lambda function or use `pd.cut()`
# 2. Display the first 10 rows showing 'Price' and 'Price_Category'
# 3. Count how many houses are in each category
#
# 💡 **Hint:** You can use nested if-else in a lambda function.
#
# **Expected outcome:** A new column with categories and a count of each category.

# %%
# Write your code here


# Display first 10


# Count categories

# %% [markdown]
# ## Task 5.2: Calculate Price Per Room
#
# **Your task:** Create a new column called 'Price_Per_Room' that shows the price divided by the number of rooms.
#
# **Instructions:**
# 1. Calculate: Price / Avg. Area Number of Rooms
# 2. Store in a new column 'Price_Per_Room'
# 3. Display the first 10 rows with 'Price', 'Avg. Area Number of Rooms', and 'Price_Per_Room'
#
# 💡 **Hint:** Simple division: `housing['Price'] / housing['Avg. Area Number of Rooms']`
#
# **Expected outcome:** A new column showing price per room for each house.

# %%
# Write your code here

# %% [markdown]
# ## Task 5.3: Create High Income Area Flag
#
# **Your task:** Create a new binary column called 'High_Income_Area' where:
# - 1 = Avg. Area Income is above $70,000
# - 0 = Avg. Area Income is $70,000 or below
#
# **Instructions:**
# 1. Use `.apply()` with a lambda function
# 2. Display the first 10 rows with 'Avg. Area Income' and 'High_Income_Area'
# 3. Count how many high income areas there are
#
# 💡 **Hint:** `lambda x: 1 if x > 70000 else 0`
#
# **Expected outcome:** A binary column indicating high income areas.

# %%
# Write your code here

# %% [markdown]
# ---
#
# # Part 6: Aggregation & Analysis 📊
#
# ## Task 6.1: Basic Statistics by Price Category
#
# **Your task:** Calculate the average income for each Price_Category.
#
# **Instructions:**
# 1. Use `.groupby()` on 'Price_Category'
# 2. Calculate the mean of 'Avg. Area Income'
# 3. Display the results
#
# 💡 **Hint:** `housing.groupby('Price_Category')['Avg. Area Income'].mean()`
#
# **Expected outcome:** Average income for Budget, Mid-Range, and Luxury categories.

# %%
# Write your code here

# %% [markdown]
# ## Task 6.2: Multiple Aggregations
#
# **Your task:** For each Price_Category, calculate:
# - Mean (average) price
# - Minimum price
# - Maximum price
# - Count of houses
#
# **Instructions:**
# 1. Use `.groupby()` with `.agg()`
# 2. Pass a list of functions: ['mean', 'min', 'max', 'count']
# 3. Display the results
#
# 💡 **Hint:** `.groupby('Price_Category')['Price'].agg(['mean', 'min', 'max', 'count'])`
#
# **Expected outcome:** A table with statistics for each price category.

# %%
# Write your code here

# %% [markdown]
# ## Task 6.3: Find Correlations
#
# **Your task:** Find which numerical features are most correlated with Price.
#
# **Instructions:**
# 1. Select only numerical columns
# 2. Calculate correlation with 'Price' using `.corr()['Price']`
# 3. Sort from highest to lowest
# 4. Answer: Which feature has the strongest correlation with Price?
#
# 💡 **Hint:** Correlation values range from -1 to 1. Higher absolute value = stronger relationship.
#
# **Expected outcome:** A sorted list of correlations with Price.

# %%
# Write your code here


# Answer: Which feature has the strongest correlation with Price?
# Answer:

# %% [markdown]
# ---
#
# # Part 7: Data Visualization 📈
#
# ## Task 7.1: Distribution of House Prices
#
# **Your task:** Create a histogram showing the distribution of house prices.
#
# **Instructions:**
# 1. Use `.plot(kind='hist')` on the 'Price' column
# 2. Set bins=30
# 3. Add a title: 'Distribution of House Prices'
# 4. Add xlabel: 'Price' and ylabel: 'Frequency'
# 5. Answer: Is the distribution symmetric or skewed?
#
# 💡 **Hint:** Use the plotting syntax you learned in the main notebook.
#
# **Expected outcome:** A histogram showing price distribution.

# %%
# Write your code here


# Answer: Is the distribution symmetric or skewed?
# Answer:

# %% [markdown]
# ## Task 7.2: Relationship Between Income and Price
#
# **Your task:** Create a scatter plot showing the relationship between Area Income and House Price.
#
# **Instructions:**
# 1. Use `.plot(kind='scatter')`
# 2. Set x='Avg. Area Income' and y='Price'
# 3. Add title: 'Income vs House Price'
# 4. Set alpha=0.5 (transparency)
# 5. Answer: Is there a positive or negative relationship?
#
# 💡 **Hint:** Positive relationship = as X increases, Y increases.
#
# **Expected outcome:** A scatter plot showing income vs price relationship.

# %%
# Write your code here


# Answer: Is there a positive or negative relationship?
# Answer:

# %% [markdown]
# ## Task 7.3: Average Price by Category
#
# **Your task:** Create a bar chart showing the average price for each Price_Category.
#
# **Instructions:**
# 1. First calculate: `avg_by_category = housing.groupby('Price_Category')['Price'].mean()`
# 2. Then plot it: `.plot(kind='bar')`
# 3. Add title: 'Average Price by Category'
# 4. Add ylabel: 'Average Price'
#
# 💡 **Hint:** Bar charts are perfect for comparing categories.
#
# **Expected outcome:** A bar chart comparing average prices across categories.

# %%
# Write your code here

# %% [markdown]
# ## Task 7.4: Multiple Scatter Plots
#
# **Your task:** Create scatter plots to explore which features affect Price the most.
#
# **Instructions:**
# Create 3 separate scatter plots:
# 1. 'Avg. Area House Age' vs 'Price'
# 2. 'Avg. Area Number of Rooms' vs 'Price'
# 3. 'Area Population' vs 'Price'
#
# For each plot:
# - Set alpha=0.3
# - Add appropriate title
#
# Answer: Which feature seems to have the strongest visual relationship with Price?
#
# 💡 **Hint:** Look for patterns - do points form a line or are they scattered randomly?
#
# **Expected outcome:** Three scatter plots showing different relationships.

# %%
# Plot 1: House Age vs Price

# %%
# Plot 2: Number of Rooms vs Price

# %%
# Plot 3: Population vs Price

# %%
# Answer: Which feature has the strongest visual relationship with Price?
# Answer:

# %% [markdown]
# ---
#
# # Part 8: Bonus Challenges 🏆
#
# ## Challenge 1: Find the Most Expensive House
#
# **Your task:** Find and display all information about the most expensive house in the dataset.
#
# **Instructions:**
# 1. Use `.idxmax()` to find the index of the maximum price
# 2. Use `.loc[]` to get the full row
# 3. Display all information about this house
#
# 💡 **Hint:** `housing.loc[housing['Price'].idxmax()]`
#
# **Expected outcome:** Full details of the most expensive house.

# %%
# Write your code here

# %% [markdown]
# ## Challenge 2: Analyze Bedroom Impact on Price
#
# **Your task:** Investigate how the number of bedrooms affects house price.
#
# **Instructions:**
# 1. Group by 'Avg. Area Number of Bedrooms'
# 2. Calculate mean, min, max price for each bedroom count
# 3. Also count how many houses have each bedroom count
# 4. Create a bar chart showing average price by bedroom count
# 5. Answer: Do more bedrooms always mean higher price?
#
# 💡 **Hint:** Round bedroom numbers first: `housing['Bedrooms_Rounded'] = housing['Avg. Area Number of Bedrooms'].round()`
#
# **Expected outcome:** Analysis and visualization of bedroom count vs price.

# %%
# Write your code here


# Answer: Do more bedrooms always mean higher price?
# Answer:

# %% [markdown]
# ## Challenge 3: Create a Price Prediction Score
#
# **Your task:** Create a simple "Desirability Score" that combines multiple features.
#
# **Instructions:**
# The formula:
# ```
# Score = (Avg. Area Income / 10000) +
#         (Avg. Area Number of Rooms * 5) +
#         (Avg. Area Number of Bedrooms * 10)
# ```
#
# 1. Create a new column 'Desirability_Score' using this formula
# 2. Find the correlation between this score and actual Price
# 3. Display the top 5 houses with highest desirability scores
# 4. Create a scatter plot: Desirability_Score vs Price
#
# 💡 **Hint:** You're creating a simple prediction model!
#
# **Expected outcome:** A new score column and analysis of its predictive power.

# %%
# Write your code here

# %% [markdown]
# ---
#
# # 🎉 Congratulations!
#
# You've completed the Pandas & EDA Exercise Notebook!
#
# ## What You've Accomplished:
#
# ✅ Loaded and explored a real-world dataset
# ✅ Inspected data quality and structure
# ✅ Filtered data with complex conditions
# ✅ Cleaned and validated data
# ✅ Created new features through engineering
# ✅ Performed aggregations and grouping
# ✅ Visualized patterns and relationships
# ✅ Tackled bonus challenges
#
# ## 📚 Key Takeaways:
#
# 1. **Always explore first** - Use `.head()`, `.info()`, `.describe()`
# 2. **Clean your data** - Check for missing values and duplicates
# 3. **Ask questions** - Use filtering and groupby to investigate
# 4. **Visualize patterns** - Charts reveal insights that numbers hide
# 5. **Create features** - Sometimes the best insights come from combining data
#
# ## 🚀 Next Steps:
#
# - Try analyzing a different dataset on your own
# - Explore more visualization libraries (seaborn, plotly)
# - Learn machine learning to make predictions from your data
# - Practice, practice, practice!
#
# ---
#
# **Remember:** Every data scientist started where you are now. Keep exploring, stay curious, and don't be afraid to make mistakes - that's how we learn! 💪
#
# ---
#
# ### 💡 Need Help?
#
# If you got stuck on any task:
# 1. Re-read the main notebook (Day1_Pandas_Basics_and_EDA.ipynb)
# 2. Check the hints provided
# 3. Try breaking the problem into smaller steps
# 4. Use Google/Stack Overflow - learning to search is a key skill!
# 5. Ask your instructor or classmates
#
# ---
#
# **Happy Data Analyzing! 📊🎯**
